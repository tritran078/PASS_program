# %%
import pandas as pd

# %% [markdown]
# 1) use markdown and code toghther using your own data
# 2) use atleast 5-10 function fromt eh wrangling data sheet
# 3) read the stat books

# %%
data = pd.read_csv("employee.csv")

# %% [markdown]
# 1) using data frame to format the data

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#     employee_id           name   department   age    salary  years_experience  \
# 0          1001  Alice Johnson  Engineering  28.0   85000.0                 4
# 1          1002      Bob Smith    Marketing  35.0   72000.0                 8
# 2          1003      Carol Lee  Engineering  31.0   92000.0                 6
# 3          1004    David Brown           HR  45.0   68000.0                15
# 4          1005     Eva Wilson      Finance  29.0   78000.0                 5
# 5          1006   Frank Miller  Engineering  38.0  105000.0                12
# 6          1007      Grace Kim    Marketing  26.0   65000.0                 2
# 7          1008    Henry Davis      Finance  41.0   95000.0                14
# 8          1009       Ivy Chen  Engineering  24.0   78000.0                 1
# 9          1010     Jack White           HR  50.0   73000.0                20
# 10         1011   Karen Garcia  Engineering  33.0       NaN                 7
# ...

# %% [markdown]
# # renaming employee id to iD

# %%
data_frame.rename(columns = {"employee_id" : "ID"})
# Out:
#       ID           name   department   age    salary  years_experience  \
# 0   1001  Alice Johnson  Engineering  28.0   85000.0                 4
# 1   1002      Bob Smith    Marketing  35.0   72000.0                 8
# 2   1003      Carol Lee  Engineering  31.0   92000.0                 6
# 3   1004    David Brown           HR  45.0   68000.0                15
# 4   1005     Eva Wilson      Finance  29.0   78000.0                 5
# 5   1006   Frank Miller  Engineering  38.0  105000.0                12
# 6   1007      Grace Kim    Marketing  26.0   65000.0                 2
# 7   1008    Henry Davis      Finance  41.0   95000.0                14
# 8   1009       Ivy Chen  Engineering  24.0   78000.0                 1
# 9   1010     Jack White           HR  50.0   73000.0                20
# 10  1011   Karen Garcia  Engineering  33.0       NaN                 7
# 11  1012  Liam Martinez    Marketing  30.0   70000.0                 5
# ...

# %% [markdown]
# ## sorting the values into ascending order (salary)

# %%
data_frame = data_frame.sort_values('salary',ascending = True)
data_frame
# Out:
#     employee_id           name   department   age    salary  years_experience  \
# 6          1007      Grace Kim    Marketing  26.0   65000.0                 2
# 3          1004    David Brown           HR  45.0   68000.0                15
# 14         1015   Olivia Lewis           HR  36.0   69000.0                10
# 19         1020     Tina Adams           HR  39.0   70000.0                11
# 11         1012  Liam Martinez    Marketing  30.0   70000.0                 5
# 17         1018   Rachel Young    Marketing  32.0   71000.0                 7
# 1          1002      Bob Smith    Marketing  35.0   72000.0                 8
# 9          1010     Jack White           HR  50.0   73000.0                20
# 16         1017     Quinn Hall      Finance  25.0   76000.0                 2
# 8          1009       Ivy Chen  Engineering  24.0   78000.0                 1
# 4          1005     Eva Wilson      Finance  29.0   78000.0                 5
# ...

# %% [markdown]
# # this is the code to do a scatter plot of the data

# %%
data_frame.plot.scatter(x = 'years_experience',y='salary')
# Out:
# <Axes: xlabel='years_experience', ylabel='salary'>

# %% [markdown]
# # drop uneeded columns

# %%
data_frame.drop(columns = ['remote_worker','performance_rating'])
# Out:
#     employee_id           name   department   age    salary  years_experience  \
# 0          1001  Alice Johnson  Engineering  28.0   85000.0                 4
# 1          1002      Bob Smith    Marketing  35.0   72000.0                 8
# 2          1003      Carol Lee  Engineering  31.0   92000.0                 6
# 3          1004    David Brown           HR  45.0   68000.0                15
# 4          1005     Eva Wilson      Finance  29.0   78000.0                 5
# 5          1006   Frank Miller  Engineering  38.0  105000.0                12
# 6          1007      Grace Kim    Marketing  26.0   65000.0                 2
# 7          1008    Henry Davis      Finance  41.0   95000.0                14
# 8          1009       Ivy Chen  Engineering  24.0   78000.0                 1
# 9          1010     Jack White           HR  50.0   73000.0                20
# 10         1011   Karen Garcia  Engineering  33.0       NaN                 7
# ...
