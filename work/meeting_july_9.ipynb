# %% [markdown]
# ##### Linear Regression

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from statsmodels) (2.4.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from statsmodels) (3.0.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/trancaominhtri/miniconda3/envs/slam_env/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
import statsmodels.formula.api as sm
import pandas as pd
import plotly.express as px
import plotly.io as pio
import numpy as np 
pio.renderers.default = "iframe"
import requests
from io import StringIO
url = "https://www.openintro.org/data/csv/possum.csv"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers)
response.raise_for_status() # Raise an exception for bad status codes
df = pd.read_csv(StringIO(response.text))

# %%
df.isna().sum()
# Out:
# site       0
# pop        0
# sex        0
# age        2
# head_l     0
# skull_w    0
# total_l    0
# tail_l     0
# dtype: int64

# %%
model = sm.ols("head_l ~ total_l",data = df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 head_l   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     93.26
# Date:                Wed, 15 Jul 2026   Prob (F-statistic):           4.68e-16
# Time:                        15:54:31   Log-Likelihood:                -245.75
# No. Observations:                 104   AIC:                             495.5
# Df Residuals:                     102   BIC:                             500.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.7098      5.173      8.257      0.000      32.450      52.970
# total_l        0.5729      0.059      9.657      0.000       0.455       0.691
# ==============================================================================
# Omnibus:                        5.577   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.117
# Skew:                           0.422   Prob(JB):                       0.0774
# Kurtosis:                       3.684   Cond. No.                     1.77e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# - extract data and follow this:
# - which problem you are trying to solve, identify objective
# - start performing linear regresison (pick one x and y)
# - explain and narrate concise description
# - do the correlation, summary, explain the constant b and m
# - find out how they are corerlated and see of my linear regression cna work that well.
# - no discrete only continous
# - using ols method and send as early as you can.
#
#
# - san diego miramar college library
# - go to ACM and search linear research paper,pick one and write notes on the paper ( have a feel of how it look like to publish a paper)
